# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'originated', 'as', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.681037
# Nearest to an: uncover, gaining, kashmiri, brokers, aarseth, ramps, strangers, grocer,
# Nearest to a: seventh, oses, hysterical, caricatured, tirthankaras, odd, tarot, dostoyevsky,
# Nearest to UNK: bono, reactionary, capacities, luis, veganism, cowboys, collateral, oxfordshire,
# Nearest to nine: bible, expropriation, lunch, bakersfield, scant, claimant, bodybuilder, arse,
# Nearest to its: smell, stopped, chinaman, jumo, rf, colloquial, kidding, dealer,
# Nearest to history: barbiturates, nightlife, redeem, northumbria, fidonet, lookups, ligatures, montesquieu,
# Nearest to while: propped, ticker, larger, bunt, pick, disable, nmi, dardanelles,
# Nearest to seven: hammer, vat, highlander, city, pillow, touched, heuvelmans, pistons,
# Nearest to six: intransitive, lf, christo, townsfolk, underlined, slow, rightarrow, venera,
# Nearest to states: saito, radio, ebionites, seizure, singing, reopening, tr, hbo,
# Nearest to they: btr, edt, thrived, gnaeus, twins, adi, opaque, sociological,
# Nearest to five: samos, admonished, microphone, chromaticity, paddock, boziz, labour, brel,
# Nearest to only: awakening, vote, insulation, vitry, tetrachloride, agena, degenerate, subtext,
# Nearest to often: measurement, afternoon, mccartney, tier, caps, vegetation, diner, masturbate,
# Nearest to one: nevada, reptile, neurotic, intoxicated, cripps, cantonese, sportsmen, murderer,
# Nearest to time: stale, core, limousine, injera, neely, commentaries, interoperable, deadly,
# Average loss at step 2000: 4.360511
# Average loss at step 4000: 3.867557
# Average loss at step 6000: 3.783010
# Average loss at step 8000: 3.689769
# Average loss at step 10000: 3.608877
# Nearest to an: the, achieving, airframes, hubble, kashmiri, duels, joh, turtledove,
# Nearest to a: the, this, imports, bloodshed, abernathy, wis, gallico, his,
# Nearest to UNK: deserves, authorisation, tattooed, serb, sulfide, bani, denounced, meditation,
# Nearest to nine: eight, five, seven, six, zero, four, three, two,
# Nearest to its: his, their, the, jehoram, switched, salisbury, mudslides, regulator,
# Nearest to history: sorbonne, remnants, redeem, refrains, barbiturates, accede, sciences, simo,
# Nearest to while: propped, are, bunt, ticker, larger, niv, phosphorylation, were,
# Nearest to seven: eight, six, five, four, three, nine, zero, two,
# Nearest to six: eight, seven, five, four, three, nine, two, zero,
# Nearest to states: radio, immunodeficiency, saito, pinnacle, oversized, ebionites, combustion, singing,
# Nearest to they: he, not, we, dilbert, there, jarmusch, niggers, superconducting,
# Nearest to five: eight, four, six, three, seven, nine, zero, two,
# Nearest to only: vote, tetrachloride, insulation, unencumbered, thessalonians, tel, institutionalized, vitry,
# Nearest to often: clowns, mccartney, also, lakota, sometimes, afternoon, tier, measurement,
# Nearest to one: two, six, eight, five, three, four, seven, zero,
# Nearest to time: equilateral, alpacas, deadly, holyhead, generators, core, limousine, polysaccharide,
# Average loss at step 12000: 3.607706
# Average loss at step 14000: 3.566409
# Average loss at step 16000: 3.408954
# Average loss at step 18000: 3.455809
# Average loss at step 20000: 3.542309
# Nearest to an: the, airframes, kashmiri, fitted, kramnik, hubble, thujone, strived,
# Nearest to a: any, the, bloodshed, coon, this, ideographic, evidently, squid,
# Nearest to UNK: denounced, serb, h, luis, rennes, plantinga, overviews, unjustified,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to its: their, his, the, whose, salisbury, switched, transl, concoction,
# Nearest to history: sorbonne, national, remnants, refrains, ast, sciences, befitting, quintana,
# Nearest to while: but, propped, are, bunt, dardanelles, were, phosphorylation, ticker,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to six: eight, seven, five, nine, four, three, zero, two,
# Nearest to states: immunodeficiency, radio, colossians, oversized, bytes, combustion, saito, singing,
# Nearest to they: we, he, there, she, not, it, you, who,
# Nearest to five: six, eight, seven, four, zero, three, two, nine,
# Nearest to only: vote, refrigerants, institutionalized, unencumbered, always, equites, tetrachloride, limited,
# Nearest to often: clowns, also, frequently, sometimes, commonly, hagia, mccartney, lakota,
# Nearest to one: two, four, three, seven, six, eight, five, nine,
# Nearest to time: polysaccharide, alpacas, reason, equilateral, years, saarland, deadly, holyhead,
# Average loss at step 22000: 3.500696
# Average loss at step 24000: 3.486983
# Average loss at step 26000: 3.480228
# Average loss at step 28000: 3.476670
# Average loss at step 30000: 3.503272
# Nearest to an: airframes, kashmiri, spoken, fitted, nusa, manning, sedgwick, kramnik,
# Nearest to a: any, the, his, no, another, diabetics, its, contextual,
# Nearest to UNK: geeks, serb, hospitaller, library, rennes, halftime, antonio, undulating,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to its: their, his, the, salisbury, concoction, our, whose, lf,
# Nearest to history: national, sorbonne, topaz, sciences, list, refrains, ast, shanks,
# Nearest to while: but, however, propped, before, dardanelles, although, where, were,
# Nearest to seven: nine, eight, five, six, four, three, zero, one,
# Nearest to six: four, eight, seven, five, nine, three, two, zero,
# Nearest to states: immunodeficiency, oversized, colossians, brazilian, radio, saito, nations, ebionites,
# Nearest to they: we, there, he, it, she, not, who, these,
# Nearest to five: four, seven, eight, three, six, nine, zero, two,
# Nearest to only: vote, either, does, always, radiotelephone, hecuba, superlative, preach,
# Nearest to often: sometimes, frequently, clowns, also, commonly, generally, there, hagia,
# Nearest to one: two, seven, eight, five, four, six, three, nine,
# Nearest to time: reason, udf, equilateral, polysaccharide, holyhead, period, sheppard, zinoviev,
# Average loss at step 32000: 3.501938
# Average loss at step 34000: 3.488557
# Average loss at step 36000: 3.454637
# Average loss at step 38000: 3.305732
# Average loss at step 40000: 3.427007
# Nearest to an: manning, inteligencia, ricardo, leonard, yearly, airframes, backbench, kashmiri,
# Nearest to a: the, another, any, hectic, bloodshed, this, idiopathic, prejudice,
# Nearest to UNK: lists, n, gangsta, transformations, pla, b, houser, abolishment,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to its: their, his, her, the, mudslides, whose, outbursts, switched,
# Nearest to history: sorbonne, list, sciences, contemporary, refrains, tongue, college, studies,
# Nearest to while: when, although, however, but, were, before, where, are,
# Nearest to seven: eight, nine, six, five, three, four, one, two,
# Nearest to six: four, five, seven, eight, three, nine, two, one,
# Nearest to states: nations, colossians, immunodeficiency, brazilian, radio, oversized, saito, ebionites,
# Nearest to they: we, there, he, you, it, she, these, i,
# Nearest to five: six, seven, four, three, two, eight, zero, nine,
# Nearest to only: either, vote, always, hecuba, another, pathway, names, radiotelephone,
# Nearest to often: sometimes, usually, frequently, also, clowns, generally, commonly, now,
# Nearest to one: seven, six, five, eight, four, nine, three, two,
# Nearest to time: polysaccharide, zinoviev, equilateral, reason, holyhead, sheppard, period, udf,
# Average loss at step 42000: 3.436398
# Average loss at step 44000: 3.453007
# Average loss at step 46000: 3.449464
# Average loss at step 48000: 3.350396
# Average loss at step 50000: 3.381843
# Nearest to an: kashmiri, manning, airframes, boycott, hubble, sedgwick, designates, schloss,
# Nearest to a: any, another, the, no, toomer, desai, keepers, thick,
# Nearest to UNK: von, admixtures, la, deserving, transformations, chicagoans, hoard, walter,
# Nearest to nine: eight, seven, six, three, four, five, two, zero,
# Nearest to its: their, his, the, her, outbursts, mudslides, arcadius, whose,
# Nearest to history: list, sorbonne, tongue, sciences, shanks, studies, contemporary, barbiturates,
# Nearest to while: when, however, although, where, but, before, though, after,
# Nearest to seven: eight, six, nine, four, three, five, two, one,
# Nearest to six: eight, seven, four, nine, five, three, two, one,
# Nearest to states: nations, kingdom, colossians, immunodeficiency, dreary, combustion, oversized, brazilian,
# Nearest to they: he, we, there, she, you, it, these, who,
# Nearest to five: six, four, eight, seven, three, zero, nine, two,
# Nearest to only: always, vote, below, either, equites, specifically, fouling, first,
# Nearest to often: sometimes, generally, frequently, usually, commonly, clowns, now, widely,
# Nearest to one: eight, six, two, four, seven, three, five, nine,
# Nearest to time: period, manner, year, reason, zinoviev, dumpling, moment, way,
# Average loss at step 52000: 3.435506
# Average loss at step 54000: 3.427527
# Average loss at step 56000: 3.437185
# Average loss at step 58000: 3.396497
# Average loss at step 60000: 3.394819
# Nearest to an: sedgwick, boycott, kashmiri, designates, airframes, gaining, ochre, hubble,
# Nearest to a: another, the, any, extremely, this, no, repopulated, desai,
# Nearest to UNK: tapped, fandom, presses, foreshadowed, rabba, landings, deductions, nls,
# Nearest to nine: eight, six, seven, five, four, three, one, two,
# Nearest to its: their, his, the, mudslides, outbursts, whose, her, arcadius,
# Nearest to history: list, economy, philosophy, tongue, tradition, topaz, oy, hawick,
# Nearest to while: although, when, though, before, including, where, however, after,
# Nearest to seven: eight, four, six, five, nine, three, one, zero,
# Nearest to six: eight, four, five, nine, seven, three, one, zero,
# Nearest to states: nations, kingdom, oversized, countries, ebionites, territories, colossians, uv,
# Nearest to they: we, there, you, he, she, these, it, not,
# Nearest to five: four, three, six, eight, seven, nine, zero, two,
# Nearest to only: always, first, below, vote, farad, either, equites, limited,
# Nearest to often: sometimes, generally, frequently, usually, commonly, also, now, widely,
# Nearest to one: four, seven, two, five, eight, six, nine, three,
# Nearest to time: period, moment, manner, game, zinoviev, reason, kinross, year,
# Average loss at step 62000: 3.237108
# Average loss at step 64000: 3.248643
# Average loss at step 66000: 3.398679
# Average loss at step 68000: 3.396300
# Average loss at step 70000: 3.354629
# Nearest to an: sedgwick, kashmiri, freiherr, airframes, ochre, credited, micron, hoisted,
# Nearest to a: another, the, any, idiopathic, squid, algorithms, msi, quantities,
# Nearest to UNK: pla, deflation, chipmunk, von, foss, transpose, dicrostonyx, nigh,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to its: their, his, the, mudslides, outbursts, whose, our, her,
# Nearest to history: list, tongue, philosophy, oy, theme, topaz, tradition, portions,
# Nearest to while: although, when, though, before, however, including, if, where,
# Nearest to seven: eight, six, four, nine, five, three, one, two,
# Nearest to six: eight, four, seven, nine, five, three, two, zero,
# Nearest to states: nations, kingdom, colossians, countries, cuailnge, territories, dreary, ebionites,
# Nearest to they: we, he, there, you, she, it, these, tishri,
# Nearest to five: four, six, seven, three, eight, nine, zero, two,
# Nearest to only: always, either, farad, still, specifically, another, names, standardised,
# Nearest to often: sometimes, usually, generally, frequently, commonly, now, also, widely,
# Nearest to one: seven, six, two, four, eight, nine, five, three,
# Nearest to time: period, moment, game, zinoviev, manner, reason, year, foldoc,
# Average loss at step 72000: 3.369888
# Average loss at step 74000: 3.347778
# Average loss at step 76000: 3.319245
# Average loss at step 78000: 3.352060
# Average loss at step 80000: 3.376533
# Nearest to an: sedgwick, airframes, boils, padres, kashmiri, outspoken, fitted, protestors,
# Nearest to a: the, another, every, any, eof, prejudice, maa, pets,
# Nearest to UNK: tragedians, straps, deserving, plutarch, antacids, reliably, bros, von,
# Nearest to nine: eight, seven, six, three, five, four, zero, one,
# Nearest to its: their, his, the, her, outbursts, mudslides, our, whose,
# Nearest to history: list, philosophy, budapest, tradition, oy, tongue, topaz, gambeson,
# Nearest to while: although, though, but, when, before, however, including, and,
# Nearest to seven: eight, six, five, nine, four, three, zero, one,
# Nearest to six: five, seven, eight, four, three, nine, one, two,
# Nearest to states: nations, kingdom, state, countries, oversized, us, cuailnge, dreary,
# Nearest to they: we, he, there, you, she, it, these, tishri,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to only: always, still, fins, headlining, standardised, until, either, adder,
# Nearest to often: sometimes, usually, generally, commonly, frequently, now, typically, also,
# Nearest to one: six, seven, eight, two, four, three, five, nine,
# Nearest to time: period, year, manner, cosby, reason, moment, years, zinoviev,
# Average loss at step 82000: 3.407829
# Average loss at step 84000: 3.406500
# Average loss at step 86000: 3.389989
# Average loss at step 88000: 3.347724
# Average loss at step 90000: 3.361676
# Nearest to an: sedgwick, another, outspoken, boycott, airframes, boils, donuts, freiherr,
# Nearest to a: the, another, dimensionless, any, oses, every, prejudice, jeffreys,
# Nearest to UNK: marsilio, senussi, fujitsu, xi, dg, cautions, jen, uniformitarianism,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to its: their, his, her, the, outbursts, our, whose, injurious,
# Nearest to history: list, philosophy, tradition, theme, budapest, tongue, topaz, evolution,
# Nearest to while: although, though, when, before, but, after, were, during,
# Nearest to seven: eight, five, six, four, nine, three, one, zero,
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to states: nations, kingdom, us, countries, territories, oversized, dreary, spartans,
# Nearest to they: we, he, there, you, she, it, these, not,
# Nearest to five: four, seven, eight, three, six, nine, two, zero,
# Nearest to only: always, even, still, sox, no, clearly, standardised, either,
# Nearest to often: sometimes, usually, generally, commonly, frequently, now, also, typically,
# Nearest to one: seven, eight, six, four, two, three, nine, five,
# Nearest to time: period, quartet, moment, reason, kan, years, participates, manner,
# Average loss at step 92000: 3.401381
# Average loss at step 94000: 3.251995
# Average loss at step 96000: 3.358500
# Average loss at step 98000: 3.240475
# Average loss at step 100000: 3.355942
# Nearest to an: sedgwick, boycott, fitted, airframes, ochre, another, donuts, padres,
# Nearest to a: another, any, the, eof, irrationality, evidently, squid, no,
# Nearest to UNK: veritable, senussi, von, cassette, payne, stadt, defines, chitin,
# Nearest to nine: eight, seven, six, four, five, three, one, zero,
# Nearest to its: their, his, the, outbursts, her, whose, our, mashal,
# Nearest to history: list, theme, geyser, peacock, aruban, tongue, budapest, portions,
# Nearest to while: although, when, though, before, however, and, but, if,
# Nearest to seven: eight, four, six, five, nine, three, zero, two,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to states: nations, kingdom, us, countries, stink, territories, state, airlines,
# Nearest to they: we, there, he, you, she, it, integrin, tishri,
# Nearest to five: seven, six, four, eight, three, nine, two, zero,
# Nearest to only: always, even, still, awt, sox, until, no, fouling,
# Nearest to often: sometimes, usually, generally, commonly, frequently, typically, now, still,
# Nearest to one: four, two, five, seven, eight, six, nine, three,
# Nearest to time: reason, period, moment, manner, year, byu, quartet, decade,

# %%
print(final_embeddings[0])
# Out:
# [-0.1440479   0.03975174 -0.17528442 -0.12330706  0.02053971 -0.00159171
#   0.11090942  0.07335592  0.05401166 -0.07665346  0.05279933 -0.08223477
#   0.20049438  0.06975389 -0.0248968  -0.01371679 -0.05382116 -0.00838494
#  -0.15698862  0.07103709 -0.05252672 -0.05630581 -0.00523722  0.08484905
#  -0.03115419 -0.03635549  0.02337363 -0.09028937  0.10672551  0.0827911
#   0.14395678  0.05094104 -0.05475089  0.10634841 -0.01355514 -0.10777563
#   0.0286637  -0.04877319 -0.04259733 -0.04404734 -0.18504836  0.00878977
#  -0.01690966  0.07501087  0.17915279  0.07547273  0.02681873 -0.03183493
#  -0.14493863 -0.02946952  0.04196183  0.02423845 -0.2248458   0.0273585
#   0.04895274  0.19003384  0.19772573  0.00703562  0.13949487  0.18983236
#   0.12383304 -0.05757028  0.03066634 -0.03508567  0.04575667  0.00615038
#   0.00160101 -0.09630298  0.2266396   0.06884112  0.05735001 -0.02419818
#   0.01164288 -0.06776118  0.03523057 -0.04033495 -0.04800244 -0.1885829
#  -0.06869008 -0.04722991 -0.05417715 -0.05719766 -0.17379788  0.08168387
#  -0.01533978 -0.03460068  0.0107416   0.0112231   0.15918642 -0.04877485
#   0.13033482 -0.07805997 -0.02741192 -0.03303537  0.11640997  0.04532747
#  -0.0194708  -0.0035344   0.02403492 -0.10440352 -0.03574741  0.16261467
#   0.03941669 -0.06211762 -0.00492089  0.0877164   0.03673454 -0.05391037
#  -0.07526169 -0.00688905 -0.01812109  0.05813135  0.04162825  0.10607121
#   0.04347233  0.04404412 -0.04829958 -0.05602866 -0.05742356  0.0322554
#   0.17192206  0.05420776  0.01492778  0.20630258  0.00053249  0.03011649
#   0.05150728 -0.00818252]

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.903044
# Nearest to one: caliber, riffing, rescue, monolithic, nose, stain, maimed, accomplishing,
# Nearest to it: waw, burks, whispered, wharton, ethan, grt, neustadt, webpage,
# Nearest to during: tupac, myself, supporter, prattica, advisor, katha, ethiopic, modesty,
# Nearest to been: reputed, schubert, dms, barbarian, fmri, relinquishing, loci, rendezvous,
# Nearest to were: baker, balochistan, parliaments, rowing, generalization, purification, quartering, claremont,
# Nearest to a: interdisciplinary, stunning, dare, laurents, braunschweig, haaretz, minced, pudding,
# Nearest to from: alerts, amyl, ciampi, saxony, versace, sierra, searchlight, melon,
# Nearest to four: requiem, band, settler, essences, caribbean, mesolithic, himalayas, radioisotope,
# Nearest to after: mckenzie, shafi, pham, originates, bok, scalars, schliemann, abv,
# Nearest to see: apparitions, boece, chalk, admixture, hornsby, peabody, durr, telophase,
# Nearest to s: digit, veered, ran, cook, freebsd, sobriquet, registered, months,
# Nearest to also: luria, ponty, reformists, faa, caches, abdomen, fanfic, lustre,
# Nearest to can: swimming, docks, krulak, arresting, fruit, devotes, nils, moons,
# Nearest to the: webs, boland, conventional, hyginus, quorum, multiverse, obeying, cimbri,
# Nearest to about: neu, au, fully, carry, lol, homeland, sorel, khmer,
# Nearest to american: hubei, countering, divinely, get, stricture, coyne, directs, flagg,
# Average loss at step 2000: 8.620071
# Average loss at step 4000: 4.897166
# Average loss at step 6000: 5.236857
# Average loss at step 8000: 4.321447
# Average loss at step 10000: 4.485728
# Nearest to one: logically, espa, orfeo, expelled, challenge, shredded, hc, smart,
# Nearest to it: this, he, there, what, prosaic, clone, ammianus, which,
# Nearest to during: after, yerba, in, when, over, accentuated, modernisation, screw,
# Nearest to been: become, hypotension, polygon, boredom, him, sla, serves, eliyahu,
# Nearest to were: are, was, had, is, wheelbase, enlightened, reductionist, supremacist,
# Nearest to a: any, the, another, an, this, scientology, each, letterboxes,
# Nearest to from: in, sloop, abolition, under, faroese, with, vessels, dxf,
# Nearest to four: seven, eight, three, nine, zero, medicinal, tide, fixation,
# Nearest to after: before, during, sells, over, electro, echoes, bandage, sextet,
# Nearest to see: function, magnitude, n, polaris, int, anti, largely, afl,
# Nearest to s: two, fpgas, shechem, ontological, parachutes, maoism, indirect, medicare,
# Nearest to also: now, which, hashes, that, mena, simulcast, partial, compaor,
# Nearest to can: may, could, would, will, should, must, to, might,
# Nearest to the: their, this, a, its, any, his, raven, reiter,
# Nearest to about: function, reference, magnitude, int, n, mother, polaris, confederacy,
# Nearest to american: british, calais, marlowe, talbot, tasman, flensburg, domineering, canadian,
# Average loss at step 12000: 3.935002
# Average loss at step 14000: 4.000536
# Average loss at step 16000: 4.035516
# Average loss at step 18000: 3.717371
# Average loss at step 20000: 3.605278
# Nearest to one: emerges, dorff, masurian, securities, alvin, statisticians, reappear, graeme,
# Nearest to it: he, she, this, there, emigrate, kronstadt, demonstrators, transsexualism,
# Nearest to during: after, through, before, over, at, since, in, throughout,
# Nearest to been: become, contributed, hearing, begun, come, busiest, depth, strings,
# Nearest to were: are, was, is, include, have, being, crux, nate,
# Nearest to a: distributed, asp, int, youth, directors, israel, chip, tiny,
# Nearest to from: due, in, since, while, among, through, although, implies,
# Nearest to four: seven, six, three, eight, nine, two, barnabas, dp,
# Nearest to after: before, during, for, bandage, cle, wherein, functionally, orchids,
# Nearest to see: pouch, apparitions, instilled, assented, waltham, uncover, overarching, saturnalia,
# Nearest to s: his, postpositions, bracketed, her, marriageable, tok, damme, ashanti,
# Nearest to also: often, still, purchases, now, boredom, hashes, indigenous, fanfic,
# Nearest to can: could, may, would, must, will, should, might, cannot,
# Nearest to the: their, his, its, our, an, each, her, catastrophism,
# Nearest to about: automaton, on, main, prosecuted, doubleday, hopeless, together, always,
# Nearest to american: osu, british, treviso, hectare, americans, leibniz, glenda, engagements,
# Average loss at step 22000: 3.650189
# Average loss at step 24000: 4.092108
# Average loss at step 26000: 3.530224
# Average loss at step 28000: 3.722851
# Average loss at step 30000: 3.752182
# Nearest to one: canis, sqq, leveraged, downing, subliminal, cosworth, sluggish, nostalgia,
# Nearest to it: he, this, there, what, dop, still, ammianus, tear,
# Nearest to during: after, before, since, until, in, throughout, through, from,
# Nearest to been: become, come, be, begun, maybe, nonzero, scurvy, sen,
# Nearest to were: are, was, is, include, crux, had, be, favors,
# Nearest to a: little, aces, semitism, bismarck, bigfoot, int, boitano, organized,
# Nearest to from: through, since, during, in, unanswered, after, starters, and,
# Nearest to four: five, seven, eight, nine, three, six, zero, gasification,
# Nearest to after: before, during, since, through, modernisation, over, orchids, later,
# Nearest to see: pouch, apparitions, hams, waltham, known, rahman, assented, references,
# Nearest to s: his, conqueror, blasphemous, burgeoning, fpgas, my, postpositions, vietnamese,
# Nearest to also: below, still, now, disambiguation, hallucinatory, usually, never, hashes,
# Nearest to can: would, could, may, should, must, might, will, cannot,
# Nearest to the: its, their, his, our, intermittently, a, jacky, lepidus,
# Nearest to about: main, israeli, hwang, dormant, wheat, adopts, montague, seldom,
# Nearest to american: subcode, americans, separates, lal, treviso, belize, foraminifera, fieldwork,
# Average loss at step 32000: 3.684738
# Average loss at step 34000: 4.182280
# Average loss at step 36000: 3.528557
# Average loss at step 38000: 3.359161
# Average loss at step 40000: 3.331784
# Nearest to one: daoxuan, bye, preparedness, statisticians, incited, sqq, sainthood, heterosexism,
# Nearest to it: he, this, she, there, still, what, emigrate, unknown,
# Nearest to during: in, since, before, throughout, until, after, within, despite,
# Nearest to been: become, come, be, praetor, maybe, remained, grown, fallen,
# Nearest to were: are, was, include, have, had, contain, became, being,
# Nearest to a: another, the, any, an, every, this, solicitors, coburg,
# Nearest to from: through, into, in, by, before, using, scrap, during,
# Nearest to four: six, three, seven, five, eight, two, bomber, zero,
# Nearest to after: before, during, for, throughout, wherein, despite, since, modernisation,
# Nearest to see: but, constituting, apparitions, waltham, includes, known, evolutionism, assented,
# Nearest to s: fpgas, whose, my, disfigured, isbn, rosalind, ashanti, its,
# Nearest to also: still, now, below, often, sometimes, hallucinatory, currently, usually,
# Nearest to can: could, may, will, must, should, would, might, cannot,
# Nearest to the: its, a, their, any, this, an, herm, his,
# Nearest to about: why, insurers, algorithmic, validated, on, hwang, rainwater, over,
# Nearest to american: canadian, americans, scripting, treviso, america, rip, hectare, dyskinesia,
# Average loss at step 42000: 3.414786
# Average loss at step 44000: 3.270407
# Average loss at step 46000: 3.294486
# Average loss at step 48000: 3.219852
# Average loss at step 50000: 3.563374
# Nearest to one: reports, antigua, consummate, imagine, order, lyr, minimax, pickling,
# Nearest to it: he, boitano, asp, traversal, switched, lucy, pmid, eucharist,
# Nearest to during: throughout, since, in, until, at, within, when, after,
# Nearest to been: become, come, remained, be, begun, already, grown, recently,
# Nearest to were: are, was, being, is, include, had, be, became,
# Nearest to a: any, the, another, no, every, coburg, solicitors, appalachians,
# Nearest to from: through, into, when, in, during, within, pyramids, by,
# Nearest to four: five, afl, int, iis, ranks, magnitude, traversal, confederacy,
# Nearest to after: before, adding, band, boitano, er, subsystem, bismarck, polaris,
# Nearest to see: includes, waltham, apparitions, known, congruences, alfalfa, constituting, dubh,
# Nearest to s: my, isbn, whose, his, sheik, revere, maoism, editable,
# Nearest to also: below, now, disambiguation, currently, hallucinatory, still, often, mena,
# Nearest to can: could, may, might, will, would, must, cannot, should,
# Nearest to the: his, a, its, their, any, our, an, another,
# Nearest to about: ischemia, pmid, bismarck, traversal, boitano, beaver, complex, lucy,
# Nearest to american: canadian, sul, scripting, professional, semitism, scribe, beaver, hamilton,
# Average loss at step 52000: 3.215924
# Average loss at step 54000: 3.238940
# Average loss at step 56000: 3.027592
# Average loss at step 58000: 3.129137
# Average loss at step 60000: 3.144697
# Nearest to one: australopithecines, sopra, camilla, ean, tamm, order, vernet, shrouded,
# Nearest to it: he, she, this, egypt, marsupial, there, proactive, which,
# Nearest to during: throughout, after, in, before, under, through, despite, until,
# Nearest to been: become, come, remained, grown, occurred, be, existed, maybe,
# Nearest to were: are, was, had, hyenas, is, being, became, be,
# Nearest to a: another, any, this, the, every, an, its, no,
# Nearest to from: through, into, starters, sheave, unless, by, thus, during,
# Nearest to four: five, three, seven, six, eight, zero, two, nine,
# Nearest to after: before, during, following, upon, heir, for, guy, arm,
# Nearest to see: includes, apparitions, include, alfalfa, but, hams, called, salute,
# Nearest to s: his, whose, her, my, their, its, our, isbn,
# Nearest to also: often, now, formerly, still, today, telescope, antietam, ischemia,
# Nearest to can: should, may, could, cannot, must, might, will, would,
# Nearest to the: its, their, a, his, any, another, our, shuffling,
# Nearest to about: over, around, placid, meriwether, jef, carol, validated, on,
# Nearest to american: canadian, australian, british, america, french, digimon, americans, hectare,
# Average loss at step 62000: 3.105684
# Average loss at step 64000: 2.985469
# Average loss at step 66000: 3.039089
# Average loss at step 68000: 3.043196
# Average loss at step 70000: 3.175734
# Nearest to one: oecs, zs, benitez, ori, bobble, camilla, shrouded, jah,
# Nearest to it: he, she, this, incompatible, ammianus, there, everyone, tear,
# Nearest to during: in, after, throughout, until, before, since, despite, through,
# Nearest to been: become, remained, come, grown, occurred, be, existed, was,
# Nearest to were: are, was, is, had, hyenas, crux, various, including,
# Nearest to a: another, the, every, any, this, gynecology, sys, appalachians,
# Nearest to from: through, into, starters, quiver, during, hence, before, in,
# Nearest to four: five, six, seven, three, feinstein, jumbo, eight, iq,
# Nearest to after: before, following, during, for, until, modernisation, within, when,
# Nearest to see: includes, schmitt, known, instilled, include, apparitions, contains, waltham,
# Nearest to s: his, whose, uan, buoyed, our, isbn, museo, fpgas,
# Nearest to also: disambiguation, below, currently, which, then, still, now, already,
# Nearest to can: could, may, should, must, cannot, will, might, would,
# Nearest to the: a, their, its, his, our, another, targ, an,
# Nearest to about: mailer, ischemia, uvular, pmid, send, kaiser, deutsch, guards,
# Nearest to american: canadian, australian, english, inaccuracies, realplayer, maclaurin, supervised, glenda,
# Average loss at step 72000: 3.028296
# Average loss at step 74000: 2.938701
# Average loss at step 76000: 3.044527
# Average loss at step 78000: 3.069884
# Average loss at step 80000: 2.901610
# Nearest to one: ean, midst, sopra, genoese, biplane, contraceptive, bye, rcs,
# Nearest to it: he, she, this, there, itself, probably, they, benefitted,
# Nearest to during: throughout, until, in, before, within, since, after, despite,
# Nearest to been: become, begun, come, grown, existed, occurred, fallen, remained,
# Nearest to were: are, was, had, include, hyenas, is, crux, various,
# Nearest to a: another, any, the, this, solicitors, gynecology, an, every,
# Nearest to from: through, via, back, allowing, sheave, starters, send, into,
# Nearest to four: seven, six, three, five, eight, zero, two, kaiser,
# Nearest to after: before, following, during, upon, arm, counterbalance, patch, coronado,
# Nearest to see: but, includes, alfalfa, called, known, instilled, apparitions, include,
# Nearest to s: whose, polygonal, maoism, his, cours, visigoth, phenotypes, nicolaus,
# Nearest to also: disambiguation, currently, now, often, usually, below, generally, which,
# Nearest to can: could, cannot, will, should, must, may, might, would,
# Nearest to the: a, their, its, his, any, an, our, milliseconds,
# Nearest to about: regarding, over, concerning, placid, validated, kaiser, coughing, approximately,
# Nearest to american: america, canadian, australian, italian, korean, americans, lal, european,
# Average loss at step 82000: 2.985872
# Average loss at step 84000: 2.971408
# Average loss at step 86000: 2.992271
# Average loss at step 88000: 3.014086
# Average loss at step 90000: 2.921196
# Nearest to one: two, dorn, battlecruiser, sqq, seven, zs, camilla, warsaw,
# Nearest to it: he, she, this, there, benefitted, actually, marsupial, rgb,
# Nearest to during: throughout, after, in, before, since, at, within, from,
# Nearest to been: become, occurred, fallen, begun, arisen, come, existed, be,
# Nearest to were: are, was, is, include, including, rigorously, prohibits, been,
# Nearest to a: another, the, any, every, this, mapquest, gynecology, coburg,
# Nearest to from: through, into, during, in, since, behind, allowing, without,
# Nearest to four: seven, five, six, three, eight, two, fishers, glock,
# Nearest to after: before, during, following, beyond, upon, without, when, afterwards,
# Nearest to see: includes, known, schmitt, accentual, dubh, but, sirhan, apparitions,
# Nearest to s: jackson, fundamentalism, uncircumcised, amanda, knitted, gnumeric, rivest, abd,
# Nearest to also: disambiguation, still, below, now, often, currently, which, sometimes,
# Nearest to can: could, may, cannot, will, should, must, might, would,
# Nearest to the: its, a, our, their, his, another, this, an,
# Nearest to about: mailer, ischemia, pmid, valley, ao, tan, gnumeric, doom,
# Nearest to american: america, canadian, australian, british, comrie, palaestina, lyricist, french,
# Average loss at step 92000: 2.958174
# Average loss at step 94000: 2.956178
# Average loss at step 96000: 2.843057
# Average loss at step 98000: 2.527265
# Average loss at step 100000: 2.765933
# Nearest to one: decentralization, battlecruiser, escaping, phony, leveraged, lyr, nikki, neurath,
# Nearest to it: she, he, this, there, still, simply, everyone, what,
# Nearest to during: throughout, despite, in, after, until, at, since, before,
# Nearest to been: become, occurred, existed, grown, begun, fallen, sen, arisen,
# Nearest to were: are, was, is, have, playground, include, being, rages,
# Nearest to a: any, the, another, something, enough, cloth, nutrition, every,
# Nearest to from: via, through, starters, by, including, towards, renovation, into,
# Nearest to four: five, six, seven, eight, two, three, hesitant, bridles,
# Nearest to after: before, following, during, despite, without, though, when, for,
# Nearest to see: refer, references, include, locate, waltham, schmitt, known, taya,
# Nearest to s: whose, his, my, her, your, campo, cours, wigner,
# Nearest to also: disambiguation, currently, below, which, still, already, actually, now,
# Nearest to can: could, must, should, cannot, might, may, will, would,
# Nearest to the: a, its, their, his, her, our, any, whitbread,
# Nearest to about: concerning, around, regarding, on, apostol, over, examined, jannah,
# Nearest to american: canadian, english, australian, british, irish, flybys, scottish, vermin,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
